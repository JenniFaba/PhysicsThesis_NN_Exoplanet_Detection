# %%
import juliet
import starsim
import numpy as np
import os
import imageio
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import time
from joblib import Parallel, delayed
import multiprocessing
import math
from pathlib import Path
from astropy.io import fits

# %%
'''def plotstuff(i, t,  rv,bi,fw,co,ph,ff_ph,ff_sp,ff_pl,ff_fc,ff_tot,ccf):
    fig = plt.figure(figsize=(10, 10))
    ax1 = plt.subplot2grid((5, 2), (0, 0))
    ax2 = plt.subplot2grid((5, 2), (1, 0))
    ax3 = plt.subplot2grid((5, 2), (2, 0))
    ax4 = plt.subplot2grid((5, 2), (3, 0))
    ax5 = plt.subplot2grid((5, 2), (4, 0))
    ax6 = plt.subplot2grid((5, 2), (0, 1))
    ax7 = plt.subplot2grid((5, 2), (1, 1))
    ax8 = plt.subplot2grid((5, 2), (2, 1))
    ax9 = plt.subplot2grid((5, 2), (3, 1))
    ax10 = plt.subplot2grid((5, 2), (4, 1))

    ax1.plot(t,rv,'ko',markersize=1)#ko es el color i la forma dels punts
    ax2.plot(t,bi,'ko',markersize=1)
    ax3.plot(t,fw,'ko',markersize=1)
    ax4.plot(t,co,'ko',markersize=1)
    ax5.plot(t,ph,'ko',markersize=1)
    ax6.plot(t,ff_ph, 'ko', markersize=1)
    ax7.plot(t, ff_sp, 'ko', markersize=1)
    ax8.plot(t, ff_tot, 'ko', markersize=1)
    ax9.plot(t, ff_fc, 'ko', markersize=1)
    ax10.plot(t, ff_pl, 'ko', markersize=1)

    xx = rv #aqui simplement afegir el text a alguna posició del gràfic
    ax1.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),'amplitude/mean/std')
    ax1.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax1.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.mean(xx),'.4f'))
    ax1.text(np.min(t),0.45*np.max(xx)+0.55*np.min(xx),format(np.std(xx),'.4f'))
    xx=bi
    ax2.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(bi)-np.min(bi),'.4f'))
    ax2.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(bi),'.4f'))
    ax2.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(bi),'.4f'))
    xx=fw
    ax3.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax3.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax3.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=co
    ax4.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax4.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax4.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ph
    ax5.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax5.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax5.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ff_ph
    ax6.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax6.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax6.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ff_sp
    ax7.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax7.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax7.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ff_tot
    ax8.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax8.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax8.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ff_fc
    ax9.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax9.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax9.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))
    xx=ff_pl
    ax10.text(np.min(t),0.9*np.max(xx)+0.1*np.min(xx),format(np.max(xx)-np.min(xx),'.4f'))
    ax10.text(np.min(t),0.75*np.max(xx)+0.25*np.min(xx),format(np.mean(xx),'.4f'))
    ax10.text(np.min(t),0.6*np.max(xx)+0.4*np.min(xx),format(np.std(xx),'.4f'))

    ax1.set_ylabel('RV')
    ax2.set_ylabel('BIS')
    ax3.set_ylabel('FWHM')
    ax4.set_ylabel('CONTRAST')
    ax5.set_ylabel('PHOT')
    ax6.set_ylabel('ff all')
    ax7.set_ylabel('ff spots')
    ax8.set_ylabel('ff all calc')
    ax9.set_ylabel('ff faculae')
    ax10.set_ylabel('ff planets')
    ax10.set_xlabel('time')
    ax5.set_xlabel('time')
    plt.tight_layout(pad=0.5, h_pad=0.5, w_pad=1) #adjusting subplots in the Figure
    plt.savefig('STARSIM_output_test2024_timeseries_plotsR40_'+str(i)+'.png', orientation='landscape', dpi=300)
    plt.close()

    #aqui comença el programa
    #length=len(ccf[:,0])-1
    #jet=plt.get_cmap('rainbow')
    #colors1=iter(jet(np.linspace(0,1,length)))
    #image_filenames = []
    # Plot each y[j,:] and save as an image
    #for j in range(length):
       # plt.plot(ccf[0,:], ccf[j+1,:], 'k-', lw=0.5, color=next(colors1))  # Example plot, replace with your plot command
      #  plt.xlabel('RV')
      #  plt.ylabel('CCF')
     #   plt.ylim(0., 1)
    #    plt.title(f'Time Step {j + i}')
        # Save the plot as an image
   #     filename = f'plot_{j + i}.png'
    #    plt.savefig(filename)
        #plt.close()  # Close the plot to prevent overlapping
   #     image_filenames.append(filename)
   # with imageio.get_writer('plotsLo150.gif', mode='I') as writer:
   #     for filename in image_filenames:
   #         image = imageio.imread(filename)
   #         writer.append_data(image)
            
   #for filename in image_filenames:
   #     os.remove(filename)

'''
def processInput(t,i,ss,tmax):

    ss.rotation_period = 24.47 #np.random.uniform(10.,50.)
    ss.spot_T_contrast = 700.# np.random.uniform(250.,1000.)
    ss.convective_shift = 1# np.random.uniform(0.5, 1.5)
    ss.differential_rotation = -2.66 #np.random.uniform(0., 2.)
    ss.inclination = 7.25# np.arcsin(np.random.uniform(0,1))
    ss.temperature_photosphere = 5772.# np.random.uniform(4000.,5000.)
    ss.mass = 1 # np.random.uniform(0.60,0.75)
    ss.radius = 1 # np.random.uniform(0.60,0.75)
    ss.logg = 5.61 #np.random.uniform(4.5,4.75)

    # More spots for testing
    overlap=True
    while overlap: 
        Nspots=1 #int(np.random.uniform(15,20))
        ss.spot_map=np.zeros([Nspots,7])
        
        for j in range(Nspots):
            ss.spot_map[j][0]=0#periods[j]#np.random.uniform(-ss.rotation_period,tmax)
            ss.spot_map[j][1]=100#lifetime[j]#np.random.uniform(25.,150.)# lifetime#
            ss.spot_map[j][2]=90.# +180./np.pi*(np.arccos(np.random.uniform(0,1))-np.arccos(np.random.uniform(0,1)))
            ss.spot_map[j][3]=np.random.uniform(270,360) #longitude
            ss.spot_map[j][4]=np.random.uniform(40,60) #spot radius

        overlap=starsim.nbspectra.check_spot_overlap(ss.spot_map,0) #true if spots are overlapping

    ss.compute_forward(observables=['rv','lc'],t=t)
    rv=ss.results['rv'] 
    bi=ss.results['bis']
    fw = ss.results['fwhm']
    co = ss.results['contrast']
    ph = ss.results['lc']
    ff_ph= ss.results['ff_ph']
    ff_sp = ss.results['ff_sp']
    ff_pl = ss.results['ff_pl']
    ff_fc = ss.results['ff_fc']
    ccf = ss.results['CCF']

    ff_tot=100.-ff_sp-ff_pl

    '''np.savetxt('STARSIM_output_test2024_timeseriesR40_{}.txt'.format(i),
               np.array([t,rv,bi,fw,co,ph,ff_ph,ff_sp,ff_pl,ff_fc,ff_tot]).T,
               fmt='%.10f')
    '''
    np.savetxt('STARSIM_output_CCFr_{}.txt'.format(i), np.array(ss.results['CCF']).T,fmt='%.10f')
    
    if i==0: file_out= open('STARSIM_parameters.txt', 'w')
    if i>0: file_out= open('STARSIM_parameters.txt', 'a')           
    
    file_out.write(str(i) + ' ' +str(ss.spot_map[0][3]) +' ' +str(ss.spot_map[0][4]) +  '\n')
    file_out.close()
    

    #plotstuff(i, t, rv,bi,fw,co,ph,ff_ph,ff_sp,ff_pl,ff_fc,ff_tot,ccf)

    
start=time.time()
Nsims=1000
t=np.arange(0,13.1,0.5)
ss=starsim.StarSim(conf_file_path='starsim.conf')

tmin=t.min()
tmax=t.max() 
num_cores = multiprocessing.cpu_count()

Parallel(n_jobs=num_cores)(delayed(processInput)(t,i,ss,tmax) for i in range(Nsims))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
